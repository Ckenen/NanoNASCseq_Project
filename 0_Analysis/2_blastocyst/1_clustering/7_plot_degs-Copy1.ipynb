# %%
from collections import defaultdict
import numpy as np
import scanpy as sc
import matplotlib.pyplot as plt

# %%
data = {
    "gene": sc.read_h5ad("results/h5ad_clustered/Blastocyst.gene_based.h5ad"),
    "transcript": sc.read_h5ad("results/h5ad_clustered/Blastocyst.transcript_based.h5ad"),
}

# %% [markdown]
# # Heatmap of DEGs

# %%
# cluster
for base in ["gene", "transcript"]:
    adata = data[base]
    sc.pl.rank_genes_groups_heatmap(
        adata, 
        n_genes=6, 
        use_raw=False, 
        groupby="CellType",
        swap_axes=True, 
        vmin=-3, 
        vmax=3, 
        cmap="coolwarm", 
        layer="scaled",
        figsize=(5, 8), 
        dendrogram=True,
        show_gene_labels=True,
        save="_of_degs.dendrogram.%s_based.pdf" % base)
# Out:
# WARNING: saving figure to file figures/heatmap_of_degs.dendrogram.gene_based.pdf
# WARNING: saving figure to file figures/heatmap_of_degs.dendrogram.transcript_based.pdf

# %%
# not cluster
for base in ["gene", "transcript"]:
    adata = data[base]
    sc.pl.rank_genes_groups_heatmap(
        adata, 
        n_genes=6, 
        use_raw=False, 
        groupby="CellType",
        swap_axes=True, 
        vmin=-3, 
        vmax=3, 
        cmap="coolwarm", 
        layer="scaled",
        figsize=(5, 8), 
        dendrogram=False,
        show_gene_labels=True,
        save="_of_degs.%s_based.pdf" % base)
# Out:
# WARNING: saving figure to file figures/heatmap_of_degs.gene_based.pdf
# WARNING: saving figure to file figures/heatmap_of_degs.transcript_based.pdf

# %% [markdown]
# # Convert gene-based marker heatmap to transcript-based

# %%
adata1 = data["gene"]
adata2 = data["transcript"]

# %%
# reordered
cts = ["PE", "EPI", "ICM-2", "ICM-1", "TE-1", "TE-2", "muralTE", "polarTE"]
cmap = plt.colormaps["tab20"]
colors = [cmap(7), cmap(5), cmap(3), cmap(1), cmap(9), cmap(11), cmap(13), cmap(15)]
adata1.obs["CellType"] = adata1.obs["CellType"].cat.reorder_categories(cts)
adata2.obs["CellType"] = adata2.obs["CellType"].cat.reorder_categories(cts)
adata1.uns["CellType_colors"] = colors
adata2.uns["CellType_colors"] = colors

# %%
genes = dict()
for ct in cts:
    genes[ct] = list(sc.get.rank_genes_groups_df(adata1, group=ct).head(6)["names"])

for ct in cts:
    tnames = list()
    for g1 in genes[ct]:
        tmp = adata2.var
        tmp = tmp[tmp["GeneName"] == g1]
        tmp = tmp.sort_values(by="n_cells", ascending=False)
        #tmp = tmp[tmp["n_cells"] > 3]
        tmp = tmp.head(5)
        tnames.extend(list(sorted(tmp.index)))
        
    ax = sc.pl.heatmap(
        adata2, 
        tnames, 
        groupby="CellType", 
        dendrogram=False, 
        swap_axes=True, 
        layer="scaled", 
        vmin=-3, 
        vmax=3, 
        cmap="coolwarm", 
        show_gene_labels=True, 
        figsize=(2.8, 5), 
        save="_of_degs.converted_from_gene_based_to_transcript_based.%s.pdf" % ct
    )
    # break
# Out:
# WARNING: saving figure to file figures/heatmap_of_degs.converted_from_gene_based_to_transcript_based.PE.pdf
# WARNING: saving figure to file figures/heatmap_of_degs.converted_from_gene_based_to_transcript_based.EPI.pdf
# WARNING: saving figure to file figures/heatmap_of_degs.converted_from_gene_based_to_transcript_based.ICM-2.pdf
# WARNING: saving figure to file figures/heatmap_of_degs.converted_from_gene_based_to_transcript_based.ICM-1.pdf
# WARNING: saving figure to file figures/heatmap_of_degs.converted_from_gene_based_to_transcript_based.TE-1.pdf
# WARNING: saving figure to file figures/heatmap_of_degs.converted_from_gene_based_to_transcript_based.TE-2.pdf
# WARNING: saving figure to file figures/heatmap_of_degs.converted_from_gene_based_to_transcript_based.muralTE.pdf
# WARNING: saving figure to file figures/heatmap_of_degs.converted_from_gene_based_to_transcript_based.polarTE.pdf

# %%
genes = dict()
for ct in cts:
    genes[ct] = list(sc.get.rank_genes_groups_df(adata1, group=ct)["names"])

for ct in cts:
    tnames = list()
    for g1 in genes[ct]:
        tmp = adata2.var
        tmp = tmp[tmp["GeneName"] == g1]
        tmp = tmp.sort_values(by="n_cells", ascending=False)
        tmp = tmp[tmp["n_cells"] > 20]
        if len(tmp) > 3:
            tmp = tmp.head(3)
        tnames.extend(list(sorted(tmp.index)))
        if len(tnames) > 20:
            break
        
    ax = sc.pl.heatmap(
        adata2, 
        tnames, 
        groupby="CellType", 
        dendrogram=False, 
        swap_axes=True, 
        layer="scaled", 
        vmin=-3, 
        vmax=3, 
        cmap="coolwarm", 
        show_gene_labels=True, 
        figsize=(2.8, 5), 
        save="_of_degs.converted_from_gene_based_to_transcript_based.high_expressed.%s.pdf" % ct,
    )
    # break
# Out:
# WARNING: saving figure to file figures/heatmap_of_degs.converted_from_gene_based_to_transcript_based.high_expressed.PE.pdf
# WARNING: saving figure to file figures/heatmap_of_degs.converted_from_gene_based_to_transcript_based.high_expressed.EPI.pdf
# WARNING: saving figure to file figures/heatmap_of_degs.converted_from_gene_based_to_transcript_based.high_expressed.ICM-2.pdf
# WARNING: saving figure to file figures/heatmap_of_degs.converted_from_gene_based_to_transcript_based.high_expressed.ICM-1.pdf
# WARNING: saving figure to file figures/heatmap_of_degs.converted_from_gene_based_to_transcript_based.high_expressed.TE-1.pdf
# WARNING: saving figure to file figures/heatmap_of_degs.converted_from_gene_based_to_transcript_based.high_expressed.TE-2.pdf
# WARNING: saving figure to file figures/heatmap_of_degs.converted_from_gene_based_to_transcript_based.high_expressed.muralTE.pdf
# WARNING: saving figure to file figures/heatmap_of_degs.converted_from_gene_based_to_transcript_based.high_expressed.polarTE.pdf

# %% [markdown]
# # Gene-based DEGs to transcript-based

# %%
adata1 = data["gene"]
adata2 = data["transcript"]

# %%
cts = ["PE", "EPI", "ICM-2", "ICM-1", "TE-1", "TE-2", "muralTE", "polarTE"]

# %%
genes = dict()
for ct in cts:
    genes[ct] = list(sc.get.rank_genes_groups_df(adata1, group=ct)["names"].values[:6])

for ct in cts:
    tnames = []
    for g1 in genes[ct]:
        tmp = adata2.var
        tmp = tmp[tmp["GeneName"] == g1]
        tmp = tmp.sort_values(by="n_cells", ascending=False)
        if len(tmp) > 3:
            tmp = tmp.head(3)
        tnames.extend(list(sorted(tmp.index)))
        
    ax = sc.pl.heatmap(
        adata2, 
        tnames, 
        groupby="CellType", 
        dendrogram=False, 
        swap_axes=True, 
        layer="scaled", 
        vmin=-3, 
        vmax=3, 
        cmap="coolwarm", 
        show_gene_labels=True, 
        figsize=(5, 5))
        # break

# %%
genes = dict()
for ct in cts:
    genes[ct] = list(sc.get.rank_genes_groups_df(adata1, group=ct)["names"].values[:6])

for ct in cts:
    tnames = []
    for g1 in genes[ct]:
        tmp = adata2.var
        tmp = tmp[tmp["GeneName"] == g1]
        tmp = tmp.sort_values(by="n_cells", ascending=False)
        if len(tmp) > 10:
            tmp = tmp.head(10)
        tnames.extend(list(sorted(tmp.index)))
        
    ax = sc.pl.heatmap(
        adata2, 
        tnames, 
        groupby="CellType", 
        dendrogram=False, 
        swap_axes=True, 
        layer="scaled", 
        vmin=-3, 
        vmax=3, 
        cmap="coolwarm", 
        show_gene_labels=True, 
        figsize=(5, 10))
        # break

# %%
tnames = {
    "PE": ["Sparc-201", "Sparc-202", "Lama1-201", "Serpinh1-201", "Col4a1-201", "Lamc1-201"],
    "EPI": ["Apoe-206", "Mylpf-201", "Mylpf-505", "Mylpf-509", "Tdh-201", "Septin1-202", "Hspb1-201"],
    "ICM-2": ["Upp1-205", "Fbp2-201", "Fabp5-201", "Tdgf1-201", "Khdc3-201", "Khdc3-204", "Mgarp-201"],
    "ICM-1": ["Bhmt-201", "Sat1-201", "Dppa3-201", "Pmm1-201", "Map1lc3b-201", "Map1lc3b-205"],
    "TE-1": ["Alppl2-201", "Hprt-201", "Isyna1-201", "Gpd1l-204", "Pemt-502"],
    "TE-2": ["Akr1b8-201", "Gm2a-201", "Dppa1-201", "Dppa1-202", "Dppa1-503"],
    "muralTE": ["BC053393-201", "Cystm1-201", "Cystm1-208", "Tspan8-201", "Tspan8-202", "Fabp3-201", "Fabp3-505", "Dkkl1-201", "Dkkl1-204"],
    "polarTE": ["H19-202", "Lgals1-201", "Actb-201", "Myl12b-201"],
}

ax = sc.pl.heatmap(
    adata2, 
    tnames, 
    groupby="CellType", 
    dendrogram=False, 
    swap_axes=True, 
    layer="scaled", 
    vmin=-3, 
    vmax=3, 
    cmap="coolwarm", 
    show_gene_labels=True, 
    figsize=(5, 10), save="_of_degs.converted_from_gene_based_to_transcript_based.pdf"
)
# Out:
# WARNING: saving figure to file figures/heatmap_of_degs.converted_from_gene_based_to_transcript_based.pdf

# %% [markdown]
# # Select some transcripts to show the advanced of full-length sequencing

# %%
adata1 = sc.read_h5ad("results/h5ad_clustered/Blastocyst.gene_based.h5ad")
adata2 = sc.read_h5ad("results/h5ad_clustered/Blastocyst.transcript_based.h5ad")

# %%
from pyBioInfo.IO.File import BedFile
with BedFile("../../../1_NanoNASCseq/results/7_assembly_custom/5_gtf_full/MouseBlastocyst.bed.gz") as f:
    transcripts = {t.name: t for t in f}

# %%
from Bio.Seq import Seq
from pyBioInfo.IO.File import FastaFile
with FastaFile("/home/chenzonggui/species/mus_musculus/GRCm38.p6/GRCm38.canonical.genome.fa") as fasta:
    for t in transcripts.values():
        cds = None
        if t.thick:
            seq = fasta.fast_fetch(obj=t)
            i1, i2, i3, i4 = t.indexes()
            cds = seq[i2:i3]
        t.cds = cds

# %%
tnames = {
    "Sparc": ["Sparc-201", "Sparc-202", "Sparc-204", "Sparc-207", "Sparc-208"],
    "Lama1": ["Lama1-201", "Lama1-203"],
    "Serpinh1": ["Serpinh1-201", "Serpinh1-202", "Serpinh1-203", "Serpinh1-205"],
    "Col4a1": ["Col4a1-201", "Col4a1-205"],
    "Lamc1": ["Lamc1-201", "Lamc1-202"],
    "Apoe": ["Apoe-205", "Apoe-206", "Apoe-210"],
    "Mylpf": ["Mylpf-203", "Mylpf-206", "Mylpf-505", "Mylpf-509"],
    "Tdh": ["Tdh-201", "Tdh-205"],
    "Septin1": ["Septin1-202", "Septin1-203", "Septin1-204", "Septin1-210"],
    "Hspb1": ["Hspb1-201", "Hspb1-501"],
    "Cystm1": ["Cystm1-201", "Cystm1-205", "Cystm1-207", "Cystm1-208"],
    "Dkkl1": ["Dkkl1-201", "Dkkl1-202", "Dkkl1-203", "Dkkl1-204"],
    "Myl12b": ["Myl12b-201", "Myl12b-203"],
}

gnames = list(tnames.keys())

# Annotate CDS
tnames3 = []
for gname, tnames2 in tnames.items():
    tnames3.extend(tnames2)
tmp = adata2.var
tmp = tmp.loc[tnames3].copy()
for gid, tmp2 in tmp.groupby(by="GeneID"):
    if len(tmp2) == 0:
        continue
    gname = tmp2["GeneName"].values[0]
    mapper = dict()
    n = 1
    for tid in tmp2["TranscriptID"]:
        t = transcripts[tid]
        t.cds_name = None
        if t.cds is not None:
            if t.cds not in mapper:
                mapper[t.cds] = "%s-CDS-%d" % (gname, n)
                n += 1
            t.cds_name = mapper[t.cds]

for tname in tnames3:
    tid = tmp.loc[tname]["TranscriptID"]
    s = transcripts[tid].cds_name
    if not isinstance(s, str):
        s = tmp.loc[tname]["TranscriptType"]
    # print(tname, s, sep="\t")
    print(s)

# Gene-based

ret = sc.pl.heatmap(
    adata1, 
    gnames, 
    groupby="CellType", 
    dendrogram=False, 
    swap_axes=True, 
    layer="scaled", 
    vmin=-3, 
    vmax=3, 
    cmap="coolwarm", 
    show_gene_labels=True, show=False, save=False,
    figsize=(5, 2.5))
ax = ret["heatmap_ax"]

# Transcript-based

ret = sc.pl.heatmap(
    adata2, 
    tnames, 
    groupby="CellType", 
    dendrogram=False, 
    swap_axes=True, 
    layer="scaled", 
    vmin=-3, 
    vmax=3, 
    cmap="coolwarm", 
    show_gene_labels=True, show=False, save=False,
    figsize=(5, 8))
ax = ret["heatmap_ax"]

y = 0
for k, v in tnames.items():
    if y > 0:
        ax.axhline(y - 0.5, color="black")
    y += len(v)
# Out:
# Sparc-CDS-1
# Sparc-CDS-2
# retained_intron
# Sparc-CDS-3
# Sparc-CDS-1
# Lama1-CDS-1
# retained_intron
# Serpinh1-CDS-1
# Serpinh1-CDS-1
# Serpinh1-CDS-1
# Serpinh1-CDS-1
# Col4a1-CDS-1
# retained_intron
# Lamc1-CDS-1
# retained_intron
# Apoe-CDS-1
# Apoe-CDS-1
# Apoe-CDS-2
# retained_intron
# Mylpf-CDS-1
# Mylpf-CDS-2
# Mylpf-CDS-3
# Tdh-CDS-1
# Tdh-CDS-2
# Septin1-CDS-1
# retained_intron
# retained_intron
# retained_intron
# Hspb1-CDS-1
# Hspb1-CDS-2
# Cystm1-CDS-1
# Cystm1-CDS-2
# Cystm1-CDS-3
# Cystm1-CDS-1
# Dkkl1-CDS-1
# Dkkl1-CDS-2
# retained_intron
# Dkkl1-CDS-3
# Myl12b-CDS-1
# retained_intron

# %%
tmp
# Out:
#                          TranscriptID           TranscriptType  \
# TranscriptName
# Sparc-201       ENSMUST00000018737.12           protein_coding
# Sparc-202        ENSMUST00000108858.7           protein_coding
# Sparc-204        ENSMUST00000125787.1          retained_intron
# Sparc-207        ENSMUST00000213866.1           protein_coding
# Sparc-208        ENSMUST00000214685.1           protein_coding
# Lama1-201        ENSMUST00000035471.8           protein_coding
# Lama1-203        ENSMUST00000233821.1          retained_intron
# Serpinh1-201     ENSMUST00000094154.5           protein_coding
# Serpinh1-202     ENSMUST00000169437.8           protein_coding
# Serpinh1-203     ENSMUST00000207849.1           protein_coding
# Serpinh1-205     ENSMUST00000208119.1           protein_coding
# Col4a1-201       ENSMUST00000033898.9           protein_coding
# Col4a1-205       ENSMUST00000209000.1          retained_intron
# Lamc1-201       ENSMUST00000027752.14           protein_coding
# Lamc1-202        ENSMUST00000159251.1          retained_intron
# Apoe-205         ENSMUST00000173739.7           protein_coding
# Apoe-206         ENSMUST00000174064.8           protein_coding
# Apoe-210         ENSMUST00000174710.1           protein_coding
# Mylpf-203        ENSMUST00000139613.1          retained_intron
# Mylpf-206        ENSMUST00000206772.1           protein_coding
# Mylpf-505               Merged.100289                  Unknown
# Mylpf-509               Merged.100293                  Unknown
# Tdh-201         ENSMUST00000022522.14           protein_coding
# Tdh-205          ENSMUST00000168669.7  nonsense_mediated_decay
# Septin1-202      ENSMUST00000106314.7           protein_coding
# Septin1-203      ENSMUST00000131208.1          retained_intron
# Septin1-204      ENSMUST00000133591.1          retained_intron
# Septin1-210      ENSMUST00000205570.1          retained_intron
# Hspb1-201        ENSMUST00000005077.6           protein_coding
# Hspb1-501                Merged.86521                  Unknown
# Cystm1-201       ENSMUST00000050584.9           protein_coding
# Cystm1-205       ENSMUST00000152804.8           protein_coding
# Cystm1-207       ENSMUST00000235576.1  nonsense_mediated_decay
# Cystm1-208       ENSMUST00000235864.1           protein_coding
# Dkkl1-201        ENSMUST00000033057.8           protein_coding
# Dkkl1-202        ENSMUST00000209466.1           protein_coding
# Dkkl1-203        ENSMUST00000210454.1          retained_intron
# Dkkl1-204        ENSMUST00000210741.1           protein_coding
# Myl12b-201       ENSMUST00000038446.9           protein_coding
# Myl12b-203       ENSMUST00000137537.1          retained_intron
#
#                                GeneID  GeneName        GeneType  Chrom  \
# TranscriptName
# Sparc-201       ENSMUSG00000018593.13     Sparc  protein_coding  chr11
# Sparc-202       ENSMUSG00000018593.13     Sparc  protein_coding  chr11
# Sparc-204       ENSMUSG00000018593.13     Sparc  protein_coding  chr11
# Sparc-207       ENSMUSG00000018593.13     Sparc  protein_coding  chr11
# Sparc-208       ENSMUSG00000018593.13     Sparc  protein_coding  chr11
# Lama1-201        ENSMUSG00000032796.8     Lama1  protein_coding  chr17
# Lama1-203        ENSMUSG00000032796.8     Lama1  protein_coding  chr17
# Serpinh1-201    ENSMUSG00000070436.12  Serpinh1  protein_coding   chr7
# Serpinh1-202    ENSMUSG00000070436.12  Serpinh1  protein_coding   chr7
# Serpinh1-203    ENSMUSG00000070436.12  Serpinh1  protein_coding   chr7
# Serpinh1-205    ENSMUSG00000070436.12  Serpinh1  protein_coding   chr7
# Col4a1-201      ENSMUSG00000031502.11    Col4a1  protein_coding   chr8
# Col4a1-205      ENSMUSG00000031502.11    Col4a1  protein_coding   chr8
# Lamc1-201       ENSMUSG00000026478.14     Lamc1  protein_coding   chr1
# Lamc1-202       ENSMUSG00000026478.14     Lamc1  protein_coding   chr1
# Apoe-205        ENSMUSG00000002985.16      Apoe  protein_coding   chr7
# Apoe-206        ENSMUSG00000002985.16      Apoe  protein_coding   chr7
# Apoe-210        ENSMUSG00000002985.16      Apoe  protein_coding   chr7
# Mylpf-203       ENSMUSG00000030672.12     Mylpf  protein_coding   chr7
# Mylpf-206       ENSMUSG00000030672.12     Mylpf  protein_coding   chr7
# Mylpf-505       ENSMUSG00000030672.12     Mylpf  protein_coding   chr7
# Mylpf-509       ENSMUSG00000030672.12     Mylpf  protein_coding   chr7
# Tdh-201         ENSMUSG00000021953.14       Tdh  protein_coding  chr14
# Tdh-205         ENSMUSG00000021953.14       Tdh  protein_coding  chr14
# Septin1-202     ENSMUSG00000000486.13   Septin1  protein_coding   chr7
# Septin1-203     ENSMUSG00000000486.13   Septin1  protein_coding   chr7
# Septin1-204     ENSMUSG00000000486.13   Septin1  protein_coding   chr7
# Septin1-210     ENSMUSG00000000486.13   Septin1  protein_coding   chr7
# Hspb1-201       ENSMUSG00000004951.10     Hspb1  protein_coding   chr5
# Hspb1-501       ENSMUSG00000004951.10     Hspb1  protein_coding   chr5
# Cystm1-201      ENSMUSG00000046727.13    Cystm1  protein_coding  chr18
# Cystm1-205      ENSMUSG00000046727.13    Cystm1  protein_coding  chr18
# Cystm1-207      ENSMUSG00000046727.13    Cystm1  protein_coding  chr18
# Cystm1-208      ENSMUSG00000046727.13    Cystm1  protein_coding  chr18
# Dkkl1-201        ENSMUSG00000030792.8     Dkkl1  protein_coding   chr7
# Dkkl1-202        ENSMUSG00000030792.8     Dkkl1  protein_coding   chr7
# Dkkl1-203        ENSMUSG00000030792.8     Dkkl1  protein_coding   chr7
# Dkkl1-204        ENSMUSG00000030792.8     Dkkl1  protein_coding   chr7
# Myl12b-201       ENSMUSG00000034868.9    Myl12b  protein_coding  chr17
# Myl12b-203       ENSMUSG00000034868.9    Myl12b  protein_coding  chr17
#
#                     Start        End Strand  n_cells  highly_variable  \
# TranscriptName
# Sparc-201        55394499   55420080      -      675             True
# Sparc-202        55394499   55419898      -      256            False
# Sparc-204        55409203   55419900      -        4            False
# Sparc-207        55395420   55420290      -        9            False
# Sparc-208        55395420   55423183      -       61            False
# Lama1-201        67697258   67822647      +      382             True
# Lama1-203        67697264   67756912      +       29            False
# Serpinh1-201     99345388   99353239      -      316             True
# Serpinh1-202     99345375   99353114      -       10            False
# Serpinh1-203     99345394   99353114      -       38            False
# Serpinh1-205     99345389   99353114      -        7            False
# Col4a1-201       11198422   11312826      -      517             True
# Col4a1-205       11245001   11245605      -       11            False
# Lamc1-201       153218921  153332786      -      793            False
# Lamc1-202       153248616  153250461      -       17            False
# Apoe-205         19696271   19698407      -       50             True
# Apoe-206         19696108   19699188      -     1448             True
# Apoe-210         19697239   19699050      -       42            False
# Mylpf-203       127213895  127214287      +       28            False
# Mylpf-206       127208898  127214288      +       47            False
# Mylpf-505       127212485  127214297      +      906            False
# Mylpf-509       127212678  127214296      +      387            False
# Tdh-201          63492346   63509092      -      422            False
# Tdh-205          63492651   63500259      -        4            False
# Septin1-202     127214461  127218498      -      207            False
# Septin1-203     127214446  127215125      -       55            False
# Septin1-204     127214965  127217039      -       18            False
# Septin1-210     127232417  127233130      -       22            False
# Hspb1-201       135887918  135889563      +     1200             True
# Hspb1-501       135887998  135889563      +       10            False
# Cystm1-201       36348696   36402980      +     1720            False
# Cystm1-205       36348773   36393370      +      200            False
# Cystm1-207       36348762   36402975      +       38            False
# Cystm1-208       36348658   36403097      +      348            False
# Dkkl1-201        45207518   45212123      -      208            False
# Dkkl1-202        45207624   45211823      -       24            False
# Dkkl1-203        45211002   45212147      -        3            False
# Dkkl1-204        45207524   45211812      -      211            False
# Myl12b-201       70973132   70990890      -     1968            False
# Myl12b-203       70974270   70975966      -       31            False
#
#                    means  dispersions  dispersions_norm             CDS
# TranscriptName
# Sparc-201       0.640988     1.999369          4.853320     Sparc-CDS-1
# Sparc-202       0.147191     0.895780          2.048644     Sparc-CDS-2
# Sparc-204       0.001241     0.085522         -0.380811             NaN
# Sparc-207       0.003796     0.110863         -0.304830     Sparc-CDS-3
# Sparc-208       0.024262     0.311307          0.296176     Sparc-CDS-1
# Lama1-201       0.398371     1.949146          6.837551     Lama1-CDS-1
# Lama1-203       0.013952     0.520002          0.921919             NaN
# Serpinh1-201    0.280639     1.535150          4.903474  Serpinh1-CDS-1
# Serpinh1-202    0.003535     0.095333         -0.351397  Serpinh1-CDS-1
# Serpinh1-203    0.015921     0.455868          0.729623  Serpinh1-CDS-1
# Serpinh1-205    0.003120     0.334923          0.366985  Serpinh1-CDS-1
# Col4a1-201      0.348272     1.186758          3.275878    Col4a1-CDS-1
# Col4a1-205      0.004302     0.312569          0.299958             NaN
# Lamc1-201       0.511041     1.242196          2.260300     Lamc1-CDS-1
# Lamc1-202       0.006820     0.184574         -0.083818             NaN
# Apoe-205        0.029362     1.047816          2.504505      Apoe-CDS-2
# Apoe-206        1.493979     2.451939          2.363299      Apoe-CDS-2
# Apoe-210        0.016544     0.401018          0.565163      Apoe-CDS-3
# Mylpf-203       0.010531     0.213381          0.002556             NaN
# Mylpf-206       0.025804     0.683511          1.412183     Mylpf-CDS-2
# Mylpf-505       0.521141     0.963395          1.305518     Mylpf-CDS-6
# Mylpf-509       0.189314     0.695221          1.447292     Mylpf-CDS-7
# Tdh-201         0.237160     0.801591          1.766230       Tdh-CDS-1
# Tdh-205         0.001316    -0.056165         -0.805642       Tdh-CDS-2
# Septin1-202     0.131619     0.870301          1.972248   Septin1-CDS-1
# Septin1-203     0.024663     0.718032          1.515690             NaN
# Septin1-204     0.007564     0.200990         -0.034595             NaN
# Septin1-210     0.007643     0.256398          0.131537             NaN
# Hspb1-201       1.077775     1.729850          2.348464     Hspb1-CDS-1
# Hspb1-501       0.004589     0.358048          0.436322     Hspb1-CDS-2
# Cystm1-201      1.556949     2.395881          2.257747    Cystm1-CDS-1
# Cystm1-205      0.090151     0.691777          1.436966    Cystm1-CDS-2
# Cystm1-207      0.015073     0.484551          0.815627    Cystm1-CDS-3
# Cystm1-208      0.159876     0.495486          0.848412    Cystm1-CDS-1
# Dkkl1-201       0.082495     0.377322          0.494112     Dkkl1-CDS-1
# Dkkl1-202       0.007568    -0.017264         -0.689005     Dkkl1-CDS-2
# Dkkl1-203       0.000938    -0.063957         -0.829005             NaN
# Dkkl1-204       0.092444     0.453028          0.721109     Dkkl1-CDS-3
# Myl12b-201      1.474033     1.520602          0.609688    Myl12b-CDS-1
# Myl12b-203      0.011383     0.284337          0.215309             NaN

# %%
# Gene-based

ret = sc.pl.dotplot(adata1, gnames, groupby="CellType", swap_axes=True, figsize=(5, 4), show=False, return_fig=True)
ax = ret.get_axes()["mainplot_ax"]
ret.show()

# Transcript-based

ret = sc.pl.dotplot(adata2, tnames, groupby="CellType", swap_axes=True, figsize=(5, 9), show=False, return_fig=True)
ax = ret.get_axes()["mainplot_ax"]
y = 0
for k, v in tnames.items():
    if y > 0:
        ax.axhline(y, color="black", lw=0.5)
    y += len(v)
ret.show()

# %%
adata = sc.read_h5ad("results/h5ad_clustered/Blastocyst.transcript_based.h5ad")

# %%
tnames = {
    "Sparc": ["Sparc-201", "Sparc-202", "Sparc-204", "Sparc-207", "Sparc-208"],
    "Lama1": ["Lama1-201", "Lama1-203"],
    "Serpinh1": ["Serpinh1-201", "Serpinh1-202", "Serpinh1-203", "Serpinh1-205"],
    "Col4a1": ["Col4a1-201", "Col4a1-205"],
    "Lamc1": ["Lamc1-201", "Lamc1-202"],
    "Apoe": ["Apoe-205", "Apoe-206", "Apoe-210"],
    "Mylpf": ["Mylpf-203", "Mylpf-206", "Mylpf-505", "Mylpf-509"],
    "Tdh": ["Tdh-201", "Tdh-205"],
    "Septin1": ["Septin1-202", "Septin1-203", "Septin1-204", "Septin1-210"],
    "Hspb1": ["Hspb1-201", "Hspb1-501"],
    "Cystm1": ["Cystm1-201", "Cystm1-205", "Cystm1-207", "Cystm1-208"],
    "Dkkl1": ["Dkkl1-201", "Dkkl1-202", "Dkkl1-203", "Dkkl1-204"],
    "Myl12b": ["Myl12b-201", "Myl12b-203"],
}

ret = sc.pl.heatmap(
    adata, 
    tnames, 
    groupby="CellType", 
    dendrogram=False, 
    swap_axes=True, 
    layer="scaled", 
    vmin=-3, 
    vmax=3, 
    cmap="coolwarm", 
    show_gene_labels=True, show=False, save=False,
    figsize=(5, 8))
ax = ret["heatmap_ax"]

y = 0
for k, v in tnames.items():
    if y > 0:
        ax.axhline(y - 0.5, color="black")
    y += len(v)

# %%
ret = sc.pl.dotplot(adata, tnames, groupby="CellType", swap_axes=True, figsize=(5, 9), show=False, return_fig=True)
ax = ret.get_axes()["mainplot_ax"]
y = 0
for k, v in tnames.items():
    if y > 0:
        ax.axhline(y, color="black", lw=0.5)
    y += len(v)
ret.savefig("a.pdf")

# %%
tnames = {
    'Actn1': ['Actn1-201', 'Actn1-202', 'Actn1-205', 'Actn1-503', 'Actn1-504'],
    'Ccdc12': ['Ccdc12-201', 'Ccdc12-202', 'Ccdc12-204', 'Ccdc12-205', 'Ccdc12-210'],
    'Folr1': ['Folr1-201', 'Folr1-202', 'Folr1-203', 'Folr1-502', 'Folr1-512'],
    'H3f3b': ['H3f3b-203', 'H3f3b-204', 'H3f3b-501', 'H3f3b-507', 'H3f3b-509'],
    'Prrc1': ['Prrc1-201', 'Prrc1-202', 'Prrc1-204', 'Prrc1-205', 'Prrc1-501'],
    'Pstk': ['Pstk-201', 'Pstk-202', 'Pstk-211', 'Pstk-501', 'Pstk-503'],
    'Rpl41': ['Rpl41-201', 'Rpl41-205', 'Rpl41-206', 'Rpl41-207', 'Rpl41-502'],
    'Snhg5': ['Snhg5-201', 'Snhg5-202', 'Snhg5-206', 'Snhg5-225', 'Snhg5-226'],
    'Srebf2': ['Srebf2-201', 'Srebf2-203', 'Srebf2-205', 'Srebf2-207'],
    'Vma21': ['Vma21-201', 'Vma21-202', 'Vma21-203', 'Vma21-204', 'Vma21-501']
}

ax = sc.pl.heatmap(
    adata, 
    tnames, 
    groupby="CellType", 
    dendrogram=False, 
    swap_axes=True, 
    layer="scaled", 
    vmin=-3, 
    vmax=3, 
    cmap="coolwarm", 
    show_gene_labels=True, 
    figsize=(5, 10))
